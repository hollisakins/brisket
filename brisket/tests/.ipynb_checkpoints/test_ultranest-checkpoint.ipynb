# %%
import numpy as np
import brisket
import sys
from astropy.io import fits

# %%
fit_instructions = {
    'redshift': (6.5,7.5),
    'galaxy1': {'model':'BC03','logMstar':(8,11),'metallicity':0.1,'sfh':'constant','age_min':0,'age_max':0.5}
}

def load_phot(ID):
    file = '/data/COSMOS-Web/catalogs/COSMOS-Web_supercatalog_pm_v0.7.fits'
    f = fits.getdata(file)
    f = f[f['id']==ID]
    fluxes = np.array([f['f_auto_f115w'][0],f['f_auto_f150w'][0],f['f_auto_f277w'][0],f['f_auto_f444w'][0]])
    errors = np.array([f['e_auto_f115w'][0],f['e_auto_f150w'][0],f['e_auto_f277w'][0],f['e_auto_f444w'][0]])
    return np.array([fluxes, errors]).T

# print(load_phot(756434))
gal = brisket.galaxy(756434, load_phot=load_phot, filt_list=['f115w','f150w','f277w','f444w'])

# %%
fit = brisket.fit(gal, fit_instructions, run='test_fit_0809', n_posterior=500)
fit.fit(verbose=True, n_live=100, use_MPI=False, sampler='ultranest')
# Out:
# {'model': 'BC03', 'logMstar': 8.576651617772642, 'metallicity': 0.1, 'sfh': 'constant', 'age_min': 0, 'age_max': 0.5, 'redshift': 7.342141978697053}
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[71], line 2
#       1 fit = brisket.fit(gal, fit_instructions, run='test_fit_0809', n_posterior=500)
# ----> 2 fit.fit(verbose=True, n_live=100, use_MPI=False, sampler='ultranest')
#
# File ~/codes/brisket/brisket/fitting/fit.py:214, in fit.fit(self, verbose, n_live, use_MPI, sampler, n_eff, discard_exploration, n_networks, pool)
#     210     n_sampler.run(verbose=verbose, n_eff=n_eff,
#     211                   discard_exploration=discard_exploration)
#     213 elif sampler == 'ultranest':
# --> 214     sampler = ReactiveNestedSampler(self.fitted_model.params,
#     215                                     self.fitted_model.lnlike,
#     216                                     transform=self.fitted_model.prior.transform,
#     217                                     log_dir='/'.join(self.fname.split('/')[:-1]),
#     218                                     resume=True,
#     219                                     run_num=None)
#     220     sampler.run(
#     221         min_num_live_points=n_live,
#     222         dlogz=0.5, # desired accuracy on logz -- could allow to specify
#    (...)
#     225         # max_num_improvement_loops=3, # how many times to go back and improve
#     226     )
#     228 os.environ["PYTHONWARNINGS"] = ""
#
# File ~/miniforge3/lib/python3.10/site-packages/ultranest/integrator.py:1208, in ReactiveNestedSampler.__init__(self, param_names, loglike, transform, derived_param_names, wrapped_params, resume, run_num, log_dir, num_test_samples, draw_multiple, num_bootstraps, vectorized, ndraw_min, ndraw_max, storage_backend, warmstart_max_tau)
#    1206 self.ndraw_max = ndraw_max
#    1207 self.build_tregion = transform is not None
# -> 1208 if not self._check_likelihood_function(transform, loglike, num_test_samples):
#    1209     assert self.log_to_disk
#    1210     if resume_similar and self.log_to_disk:
#
# File ~/miniforge3/lib/python3.10/site-packages/ultranest/integrator.py:1271, in ReactiveNestedSampler._check_likelihood_function(self, transform, loglike, num_test_samples)
#    1267 assert np.shape(p) == (num_test_samples, self.num_params), (
#    1268     "Error in transform function: returned shape is %s, expected %s" % (
#    1269         np.shape(p), (num_test_samples, self.num_params)))
#    1270 logl = loglike(p)
# -> 1271 assert np.logical_and(u > 0, u < 1).all(), (
#    1272     "Error in transform function: u was modified!")
#    1273 assert np.shape(logl) == (num_test_samples,), (
#    1274     "Error in loglikelihood function: returned shape is %s, expected %s" % (np.shape(logl), (num_test_samples,)))
#    1275 assert np.isfinite(logl).all(), (
#    1276     "Error in loglikelihood function: returned non-finite number: %s for input u=%s p=%s" % (logl, u, p))
#
# AssertionError: Error in transform function: u was modified!

# %%
import numpy as np
x = np.linspace(400, 800, 100)
yerr = 1.0
y = np.random.normal(20 * np.exp(-0.5 * ((x-500)/4.2)**2), yerr)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.errorbar(x, y, yerr=yerr, ls=' ', marker='x')
plt.plot(x, 20 * np.exp(-0.5 * ((x-500)/4.2)**2), ls=':', alpha=0.5, color='k')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
param_names = ['location', 'amplitude', 'width']

import scipy.stats

def my_prior_transform(cube):
    params = cube.copy()

    # transform location parameter: uniform prior
    lo = 400
    hi = 800
    params[0] = cube[0] * (hi - lo) + lo

    # transform amplitude parameter: log-uniform prior
    lo = 0.1
    hi = 100
    params[1] = 10**(cube[1] * (np.log10(hi) - np.log10(lo)) + np.log10(lo))

    # More complex prior, you can use the ppf functions
    # from scipy.stats, such as scipy.stats.norm(mean, std).ppf

    # transform for width:
    # a log-normal centered at 1 +- 1dex
    params[2] = 10**scipy.stats.norm.ppf(cube[2], 0, 1)

    return params

# %%
from numpy import log

def my_likelihood(params):
    location, amplitude, width = params
    # compute intensity at every x position according to the model
    y_model = amplitude * np.exp(-0.5 * ((x - location)/width)**2)
    # compare model and data with gaussian likelihood:
    like = -0.5 * (((y_model - y)/yerr)**2).sum()
    return like

# %%
import ultranest

sampler = ultranest.ReactiveNestedSampler(param_names, my_likelihood, my_prior_transform, log_dir='ultranest/test_run', resume=True)

# %%
result = sampler.run()
# Out:
# [ultranest] Resuming from 4431 stored points
# VBox(children=(HTML(value=''), GridspecLayout(children=(HTML(value="<div style='background-color:#6E6BF4;'>&nb…
# [ultranest] Explored until L=-6e+01   [-56.9297..-56.9296]*| it/evals=4202/14829 eff=inf% N=207 7
# [ultranest] Likelihood function evaluations: 14829
# [ultranest] Writing samples and results to disk ...
# [ultranest] Writing samples and results to disk ... done
# [ultranest]   logZ = -71.5 +- 0.1975
# [ultranest] Effective samples strategy satisfied (ESS = 968.7, need >400)
# [ultranest] Posterior uncertainty strategy is satisfied (KL: 0.47+-0.09 nat, need <0.50 nat)
# [ultranest] Evidency uncertainty strategy is satisfied (dlogz=0.20, need <0.5)
# [ultranest]   logZ error budget: single: 0.25 bs:0.20 tail:0.01 total:0.20 required:<0.50
# [ultranest] done iterating.

# %%
sampler.print_results()
# Out:
# logZ = -71.520 +- 0.470
#   single instance: logZ = -71.520 +- 0.182
#   bootstrapped   : logZ = -71.498 +- 0.470
#   tail           : logZ = +- 0.010
# insert order U test : converged: True correlation: inf iterations
#
#     location            : 498.95│ ▁ ▁▁▁▁▁▁▁▁▂▂▂▄▅▄▆▇▆▇▆▆▆▄▅▃▃▃▁▁▁▁▁▁▁▁▁ │500.69    499.86 +- 0.21
#     amplitude           : 16.47 │ ▁▁▁▁▁▁▁▂▂▂▃▄▅▅▆▇▇▇▇▇▅▅▄▄▂▂▁▁▂▁▁▁▁▁ ▁▁ │23.41     19.71 +- 0.87
#     width               : 3.24  │ ▁ ▁▁▁▁▁▁▂▁▂▃▄▄▅▅▆▇▇▆▅▄▄▃▃▃▂▁▂▁▁▁▁▁▁▁▁ │5.04      4.13 +- 0.22

# %%
dir(sampler)
# Out:
# ['Lmin',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_adaptive_strategy_advice',
#  '_check_likelihood_function',
#  '_create_point',
#  '_expand_nodes_before',
#  '_find_strategy',
#  '_refill_samples',
#  '_set_likelihood_function',
#  '_setup_distributed_seeds',
#  '_should_node_be_expanded',
#  '_update_region',
#  '_update_results',
#  '_widen_nodes',
#  '_widen_roots',
#  '_widen_roots_beyond_initial_plateau',
#  'build_tregion',
#  'cluster_num_live_points',
#  'comm',
#  'derivedparamnames',
#  'draw_multiple',
#  'ib',
#  'likes',
#  'live_points_healthy',
#  'log',
#  'log_to_disk',
#  'log_to_pointstore',
#  'logger',
#  'loglike',
#  'logs',
#  'min_num_live_points',
#  'mpi_rank',
#  'mpi_size',
#  'ncall',
#  'ncall_region',
#  'ndraw_max',
#  'ndraw_min',
#  'num_bootstraps',
#  'num_params',
#  'paramnames',
#  'plot',
#  'plot_corner',
#  'plot_run',
#  'plot_trace',
#  'pointpile',
#  'pointstore',
#  'print_results',
#  'region',
#  'region_class',
#  'region_nodes',
#  'results',
#  'root',
#  'run',
#  'run_iter',
#  'run_sequence',
#  'sampler',
#  'samples',
#  'samplesv',
#  'sampling_slow_warned',
#  'stepsampler',
#  'store_tree',
#  'transform',
#  'transformLayer',
#  'transform_layer_class',
#  'transform_limits',
#  'tregion',
#  'use_mpi',
#  'use_point_stack',
#  'volfactor',
#  'wrapped_axes',
#  'x_dim']

# %%
sampler.results
# Out:
# {'niter': 4431,
#  'logz': -71.52021706488995,
#  'logzerr': 0.47009983160057156,
#  'logz_bs': -71.49800996318967,
#  'logz_single': -71.52021706488995,
#  'logzerr_tail': 0.00991120235741505,
#  'logzerr_bs': 0.46999534012446986,
#  'ess': 968.6814541501142,
#  'H': 13.1987847824156,
#  'Herr': 0.19800133561909397,
#  'posterior': {'mean': [499.85720294133375,
#    19.705480025401183,
#    4.1303837334524225],
#   'stdev': [0.21458139464279666, 0.8719517807822573, 0.2243557628135452],
#   'median': [499.85476404404426, 19.711686092856446, 4.1248916689983535],
#   'errlo': [499.6439826992028, 18.806187778475515, 3.9097394234742846],
#   'errup': [500.07556919371643, 20.582849245488372, 4.359985345637756],
#   'information_gain_bits': [4.14647919764959,
#    3.681513355348153,
#    3.597925549367407]},
#  'weighted_samples': {'upoints': array([[0.12304562, 0.93006429, 0.98024196],
#          [0.11787406, 0.96657292, 0.95787211],
#          [0.2399437 , 0.96040053, 0.95343547],
#          ...,
#          [0.24962642, 0.76535588, 0.73091149],
#          [0.24961659, 0.76484813, 0.73044041],
#          [0.24957575, 0.76536173, 0.73047941]]),
#   'points': array([[449.21824868,  61.68688741, 114.49116367],
#          [447.1496248 ,  79.3814012 ,  53.27329904],
#          [495.97748064,  76.06792773,  47.76589256],
#          ...,
#          [499.85056675,  19.77277576,   4.12640653],
#          [499.84663727,  19.70354563,   4.11287487],
#          [499.83029824,  19.77357421,   4.11399305]]),
#   'weights': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          4.93360514e-05, 4.93558546e-05, 4.94185141e-05]),
#   'logw': array([ -5.99271429,  -5.99521429,  -5.99771429, ..., -24.55584279,
#          -24.55584279, -24.55584279]),
#   'bootstrapped_weights': array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [7.67790862e-05, 8.53187805e-05, 0.00000000e+00, ...,
#           8.18509121e-05, 0.00000000e+00, 7.39668141e-05],
#          [7.68099049e-05, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 7.39965039e-05],
#          [7.69074186e-05, 0.00000000e+00, 0.00000000e+00, ...,
#           8.19877217e-05, 1.08847940e-04, 0.00000000e+00]]),
#   'logl': array([-6.83764884e+04, -6.47081039e+04, -5.73675008e+04, ...,
#          -5.68812298e+01, -5.68808284e+01, -5.68795597e+01])},
#  'samples': array([[500.16866778,  18.5597953 ,   4.19921789],
#         [499.57649309,  20.15796712,   4.39819879],
#         [499.83019102,  19.90291781,   4.27460502],
#         ...,
#         [500.19017689,  20.90058127,   3.99333766],
#         [499.69919829,  19.08787885,   4.3121994 ],
#         [500.18559553,  20.45674706,   4.07402439]]),
#  'maximum_likelihood': {'logl': -56.879559696355216,
#   'point': [499.8302982377064, 19.773574209780556, 4.113993052114007],
#   'point_untransformed': [0.2495757455942661,
#    0.7653617260431107,
#    0.730479408841547]},
#  'ncall': 14829,
#  'paramnames': ['location', 'amplitude', 'width'],
#  'logzerr_single': 0.18165065911259173,
#  'insertion_order_MWW_test': {'independent_iterations': inf,
#   'converged': True}}
